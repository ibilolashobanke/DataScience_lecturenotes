# %% [markdown]
# ## Required Reading on Functions
#
# Function

# %%
# Function calls
type(32)
# Out:
# int

# %% [markdown]
# ### Built-in functions

# %%
# Max represent the last alphabet in acending order
max('Hello world')
# Out:
# 'w'

# %%
# Min represent the first alphabet in acending order
min('Hello world')
# Out:
# ' '

# %%
# total lenght of word including white spaces
len('Hello world')
# Out:
# 11

# %% [markdown]
# ### Type conversion functions

# %%
# converting string to integer
int('32')
# Out:
# 32

# %%
# cannot convert to integer because it doesn't match
int('Hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-f9d9d26b3128> in <module>
#       1 # cannot convert to integer because it doesn't match
# ----> 2 int('Hello')
#
# ValueError: invalid literal for int() with base 10: 'Hello'

# %%
#int can convert floating-point values to integers, but it doesn’t round off; it chops off the fraction part
int(3.99999)

# %%
# Convert to integer
int(-2.3)
# Out:
# -2

# %%
#float converts integers and strings to floating-point numbers
float(32)
# Out:
# 32.0

# %%
float('3.14159')
# Out:
# 3.14159

# %%
# str converts its argument to a string
str(32)
# Out:
# '32'

# %%
str(3.14159)
# Out:
# '3.14159'

# %% [markdown]
# ### Random numbers

# %%
import random
for i in range(10):
    x = random.random()
print(x)
# Out:
# 0.4377588846561723

# %%
# randint takes the parameters low and high, and returns an integer between low and high (including both).
random.randint(5, 10)
# Out:
# 9

# %%
t = [1, 2, 3]

# %%
random.choice(t)
# Out:
# 1

# %% [markdown]
# ### Math functions

# %%
import math

# %%
print(math)
# Out:
# <module 'math' (built-in)>

# %%
ratio = signal_power / noise_power
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-ecb0f8638358> in <module>
# ----> 1 ratio = signal_power / noise_power
#
# NameError: name 'signal_power' is not defined

# %%
decibels = 10 * math.log10(ratio)

# %%
radians = 0.7

# %%
height = math.sin(radians)

# %%
# convert from degrees to radians
degrees = 45

# %%
radians = degrees / 360.0 * 2 * math.pi
# The expression math.pi gets the variable pi from the math module. The value of
# this variable is an approximation of π, accurate to about 15 digits

# %%
math.sin(radians)
# Out:
# 0.7071067811865475

# %% [markdown]
# ### ADDING NEW FUNCTIONS
# A function definition specifies the name of a new
# function and the sequence of statements that execute when the function is called.

# %%
# def is a keyword that indicates that this is a function definition
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print('I sleep all night and I work all day.')

# %%
# No output because it's in a function not a variable
print(print_lyrics)
# Out:
# <function print_lyrics at 0x7fea336490e0>

# %%
print(type(print_lyrics))
# Out:
# <class 'function'>

# %%
print_lyrics()
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.

# %%
def repeat_lyrics():
    print_lyrics()
    print_lyrics()

# %%
repeat_lyrics()
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.

# %% [markdown]
# ### Definitions and uses

# %%
def print_lyrics():
    print("I'm a lumberjack, and I'm okay.")
    print('I sleep all night and I work all day.')

# %%
def repeat_lyrics():
    print_lyrics()
    print_lyrics()

# %% [markdown]
# ### FLOW OF EXECUTION

# %%
repeat_lyrics()
# Out:
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.
# I'm a lumberjack, and I'm okay.
# I sleep all night and I work all day.

# %% [markdown]
# ### Parameters and arguments

# %%
def print_twice(bruce):
    print(bruce)
    print(bruce)

# %%
print_twice('Spam')
# Out:
# Spam
# Spam

# %%
print_twice(17)
# Out:
# 17
# 17

# %%
# Import library
import math

# %%
print_twice(math.pi)
# Out:
# 3.141592653589793
# 3.141592653589793

# %%
print_twice('Spam '*4)
# Out:
# Spam Spam Spam Spam
# Spam Spam Spam Spam

# %%
print_twice(math.cos(math.pi))
# Out:
# -1.0
# -1.0

# %%
michael = 'Eric, the half a bee.'

# %%
print_twice(michael)
# Out:
# Eric, the half a bee.
# Eric, the half a bee.

# %% [markdown]
# ### Fruitful functions and void functions

# %%
x = math.cos(radians)
golden = (math.sqrt(5) + 1) / 2

# %%
# Squareroot
math.sqrt(5)
# Out:
# 2.23606797749979

# %%
result = print_twice('Bing')
# Out:
# Bing
# Bing

# %%
print(result)
# Out:
# None

# %%
print(type(None))
# Out:
# <class 'NoneType'>

# %%
def addtwo(a, b):
    added = a + b
    return added

x = addtwo(3, 5)
print(x)
# Out:
# 8
