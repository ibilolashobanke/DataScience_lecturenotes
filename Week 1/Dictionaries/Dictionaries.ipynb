# %% [markdown]
# ## Week 1: Day 4 – Dictionaries

# %% [markdown]
# A dictionary consists of keys and values. It is helpful to compare a dictionary to a list. Instead of the numerical indexes such as a list, dictionaries have keys. These keys are used to access values within a dictionary.

# %%
# Importing necessary packages for displaying images
from PIL import Image
import numpy as np
from IPython.display import display

# %%
im=Image.open('DictsList.png')
display(im)
array=np.array
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=2208x1490 at 0x213055A25B0>

# %%
# Creating an empty dictionary
purse= dict()

# %%
# Lists index their entries based on the position in the list
# Dictionaries are like bags - no order
# So we index the things we put in the dictionary with a “lookup tag”
purse["money"]=12
purse["candy"]=3
purse["tissues"]=75
print(purse)
# Out:
# {'money': 12, 'candy': 3, 'tissues': 75}

# %%
print(purse['candy'])
# Out:
# 3

# %%
purse['candy'] = purse['candy'] + 2
print(purse)
# Out:
# {'money': 12, 'candy': 10, 'tissues': 75}

# %%
# Dictionaries are like lists except that they use keys instead of numbers to look up values
ddd = dict()
ddd['age'] = 21
ddd['course'] = 182
print(ddd)
# Out:
# {'age': 21, 'course': 182}

# %%
ddd['age'] = 23
print(ddd)
# Out:
# {'age': 23, 'course': 182}

# %%
# Dictionary literals use curly braces and have a list of key : value pairs
jjj = { 'chuck' : 1 , 'fred' : 42, 'jan': 100}
print(jjj)
# Out:
# {'chuck': 1, 'fred': 42, 'jan': 100}

# %%
# You can make an empty dictionary using empty curly braces
ooo = { }
print(ooo)
# Out:
# {}

# %%
# One common use of dictionaries is counting how often we “see” something
ccc = dict()
ccc['csev'] = 1
ccc['cwen'] = 1
print(ccc)
# Out:
# {'csev': 1, 'cwen': 1}

# %%
ccc['cwen'] = ccc['cwen'] + 1
print(ccc)
# Out:
# {'csev': 1, 'cwen': 2}

# %%
# It is an error to reference a key which is not in the dictionary
ccc = dict()
print(ccc['csev'])

# %%
# We can use the "in" operator to see if a key is in the dictionary
'csev' in ccc
# Out:
# False

# %%
# When we encounter a new name, we need to add a new entry in the dictionary and if this the second or later time we have seen the name, we simply add one to the count in the dictionary under that name
counts = dict()
names = ['csev', 'cwen', 'csev', 'zqian', 'cwen']
for name in names :
    if name not in counts: 
       counts[name] = 1
    else :
        counts[name] = counts[name] + 1
print(counts)
# Out:
# {'csev': 2, 'cwen': 2, 'zqian': 1}

# %%
# The pattern of checking to see if a key is already in a dictionary and assuming a default value if the key is not there is so common that there is a method called get() that does this for us
if name in counts:
       x = counts[name]
else :
    x = 0

# %%
x = counts.get(name, 0)

# %%
# We can use get() and provide a default value of zero when the key is not yet in the dictionary - and then just add one
counts = dict()
names = ['csev', 'cwen', 'csev', 'zqian', 'cwen']
for name in names :
    counts[name] = counts.get(name, 0) + 1
print(counts)
# Out:
# {'csev': 2, 'cwen': 2, 'zqian': 1}

# %%
# The general pattern to count the words in a line of text is to split the line into words, then loop through the words and use a dictionary to track the count of each word independently.
counts = dict()
print('Enter a line of text:')
line = input('')

words = line.split()

print('Words:', words)

print('Counting...')
for word in words:
    counts[word] = counts.get(word,0) + 1
print('Counts', counts)
# Out:
# Enter a line of text:
#  the clown ran after the car and the car ran into the tent and the tent fell down on the clown and the car
# Words: ['the', 'clown', 'ran', 'after', 'the', 'car', 'and', 'the', 'car', 'ran', 'into', 'the', 'tent', 'and', 'the', 'tent', 'fell', 'down', 'on', 'the', 'clown', 'and', 'the', 'car']
# Counting...
# Counts {'the': 7, 'clown': 2, 'ran': 2, 'after': 1, 'car': 3, 'and': 3, 'into': 1, 'tent': 2, 'fell': 1, 'down': 1, 'on': 1}

# %% [markdown]
# ## Definite Loops and Dictionaries

# %% [markdown]
# Even though dictionaries are not stored in order, we can write a for loop that goes through all the entries in a dictionary - actually it goes through all of the keys in the dictionary and looks up the values

# %%
counts = { 'chuck' : 1 , 'fred' : 42, 'jan': 100}
for key in counts:
    print(key, counts[key])
# Out:
# chuck 1
# fred 42
# jan 100

# %%
# You can get a list of keys, values, or items (both) from a dictionary
jjj = { 'chuck' : 1 , 'fred' : 42, 'jan': 100}
print(list(jjj))
# Out:
# ['chuck', 'fred', 'jan']

# %%
# The keys() method returns a view object. The view object contains the keys of the dictionary, as a list.
print(jjj.keys())
# Out:
# dict_keys(['chuck', 'fred', 'jan'])

# %%
# The values() method returns a view object. The view object contains the values of the dictionary, as a list.
print(jjj.values())
# Out:
# dict_values([1, 42, 100])

# %%
# # The items() method returns a view object. The view object contains the key-value pairs of the dictionary, as tuples in a list.
print(jjj.items())
# Out:
# dict_items([('chuck', 1), ('fred', 42), ('jan', 100)])

# %%
# We loop through the key-value pairs in a dictionary using *two* iteration variables
# Each iteration, the first variable is the key and the second variable is the corresponding value for the key
jjj = { 'chuck' : 1 , 'fred' : 42, 'jan': 100}
for aaa,bbb in jjj.items() :
    print(aaa, bbb)
# Out:
# chuck 1
# fred 42
# jan 100

# %%
#ask for input for file name
name = input('Enter file:')
#open our file
handle = open(name)
# Out:
# Enter file: words.txt

# %%
#define count outside the loop as empty
counts = dict()
#for each line in our file
for line in handle:
#use split command to split and take the words individually
    words = line.split()
#words is a list    
    for word in words:
#will go to each word and adds its frequency      
        counts[word] = counts.get(word,0) + 1

# %%
#Creating the variables to hold the word with the largest count
bigcount = None
bigword = None
#assigns the counts.items to the items in the counts dictionary. If bigcount is None or less than the current iteration variable, the new word is stored and the count is updated in bigword and bigcount respectively. 
for word,count in counts.items():
    if bigcount is None or count > bigcount:
        bigword = word
        bigcount = count

# %%
print(bigword, bigcount)
# Out:
# to 16

# %% [markdown]
# ## Iterating over the Contents of a Dictionary

# %%
file_counts={'jpg':10, 'txt':14, 'csv':2, 'py':23}
for extension in file_counts:
    print(extension)
# Out:
# jpg
# txt
# csv
# py

# %%
for ext, amount in file_counts.items():
    print('There are {} files with the .{} extention'.format(amount, ext))
# Out:
# There are 10 files with the .jpg extention
# There are 14 files with the .txt extention
# There are 2 files with the .csv extention
# There are 23 files with the .py extention

# %%
file_counts.keys()
# Out:
# dict_keys(['jpg', 'txt', 'csv', 'py'])

# %%
file_counts.values()
# Out:
# dict_values([10, 14, 2, 23])

# %%
######

# %%
def count_letters(text):
    result = {}
# Go through each letter in the text
    for letter in text:
# Check if the letter needs to be counted or not
      if letter not in result:
          result[letter] = 0
# Add or increment the value in the dictionary
      result[letter] += 1
    return result

# %%
# Use the count() Function to Count the Number of a Characters Occuring in a String in
print(count_letters("aaaaa"))
# Out:
# {'a': 5}

# %%
print(count_letters("tenant"))
# Out:
# {'t': 2, 'e': 1, 'n': 2, 'a': 1}

# %%
print(count_letters("a long string with a lot of letters"))
# Out:
# {'a': 2, ' ': 7, 'l': 3, 'o': 3, 'n': 2, 'g': 2, 's': 2, 't': 5, 'r': 2, 'i': 2, 'w': 1, 'h': 1, 'f': 1, 'e': 2}

# %% [markdown]
# ## Sets and Dictionaries

# %%
d1={}
print(d1)
type(d1)
# Out:
# {}
# dict

# %%
# One or more “key: value” pairs, separated by commas, are put inside curly brackets to form a dictionary object.
d2={1:"welcome", 2:"to", 3:"python", 4:"tutorial"}
print(d2)
# Out:
# {1: 'welcome', 2: 'to', 3: 'python', 4: 'tutorial'}

# %%
d3={"name":"Sam", "age":22, "profession":"student"}
print(d3)
# Out:
# {'name': 'Sam', 'age': 22, 'profession': 'student'}

# %%
d4 = dict({})

# %%
d4=dict({1:"welcome", 2:"to", 3:"python", 4:"tutorial"})
print(d4)
# Out:
# {1: 'welcome', 2: 'to', 3: 'python', 4: 'tutorial'}

# %%
d5=([(1,"welcome"), (2,"to"), (3,"python"), (4,"tutorial")])
print(d5)

# %%
d6={"name":{"first":"Sam", "last":"Crew"}, "age":22, "profession":"student"}
print(d6)
# Out:
# {'name': {'first': 'Sam', 'last': 'Crew'}, 'age': 22, 'profession': 'student'}

# %% [markdown]
# ## Adding Elements

# %%
d={}
d[0]="welcome"
print(d)
# Out:
# {0: 'welcome'}

# %%
d[1]=("How", "are",  "you")
print(d)
# Out:
# {0: 'welcome', 1: ('How', 'are', 'you')}

# %%
d["name"]="Sam"
print(d)
# Out:
# {0: 'welcome', 1: ('How', 'are', 'you'), 'name': 'Sam'}

# %%
d["name"]={"first":"Sam", "last":"Crew"}
print(d)
# Out:
# {0: 'welcome', 1: ('How', 'are', 'you'), 'name': {'first': 'Sam', 'last': 'Crew'}}

# %% [markdown]
# ## Accesing Elements

# %%
print(d)
# Out:
# {0: 'welcome', 1: ('How', 'are', 'you'), 'name': {'first': 'Sam', 'last': 'Crew'}}

# %%
print(d["name"])
# Out:
# {'first': 'Sam', 'last': 'Crew'}

# %%
print(d["name"]["first"])
# Out:
# Sam

# %%
print(d.get(1))
# Out:
# ('How', 'are', 'you')

# %% [markdown]
# ## Deleting Elements

# %%
print(d)
# Out:
# {0: 'welcome', 1: ('How', 'are', 'you'), 'name': {'first': 'Sam', 'last': 'Crew'}}

# %%
# The pop() method removes the element at the specified position.
d.pop(0)
# Out:
# 'welcome'

# %%
print(d)
# Out:
# {1: ('How', 'are', 'you'), 'name': {'first': 'Sam', 'last': 'Crew'}}

# %%
# The popitem() method removes the item that was last inserted into the dictionary.
d.popitem()
# Out:
# ('name', {'first': 'Sam', 'last': 'Crew'})

# %%
print(d)
# Out:
# {1: ('How', 'are', 'you')}

# %%
print(d)
# Out:
# {1: ('How', 'are', 'you')}

# %% [markdown]
# ## Built in Functions

# %%
d.values()
# Out:
# dict_values([('How', 'are', 'you')])

# %%
keys={"a", "b", "c", "d"}
value=1
# The fromkeys() method returns a dictionary with the specified keys and the specified value.
dict.fromkeys(keys,value)
# Out:
# {'c': 1, 'b': 1, 'd': 1, 'a': 1}

# %%
#The clear() method removes all the elements from a dictionary.
d.clear()
print(d)
# Out:
# {}

# %% [markdown]
# ## Sets

# %% [markdown]
#  A set is an unordered collection of items. Set items are unique and immutable. In this reference page, you will find all the methods that a set object can use.

# %%
s=set([1,2,3,4,])
print(s)
type(s)
# Out:
# {1, 2, 3, 4}
# set

# %%
# The add() method adds an element to the set.
s.add("a")
print(s)
# Out:
# {1, 2, 3, 4, 'a'}

# %%
print(s)
# Out:
# {1, 2, 3, 4, 'a'}

# %%
# The frozenset() function returns an unchangeable frozenset object (which is like a set object, only unchangeable).
fs=frozenset([1,2,3,4,])
print(fs)
# Out:
# frozenset({1, 2, 3, 4})

# %%
s1=set([1,3,7,2])
s2=set([3,2,8,9])

# %%
# The union() method returns a set that contains all items from the original set, and all items from the specified set(s).
# You can specify as many sets you want, separated by commas.
# It does not have to be a set, it can be any iterable object.
# If an item is present in more than one set, the result will contain only one appearance of this item.
s1.union(s2)
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
# The difference() method returns a set that contains the difference between two sets.
# Meaning: The returned set contains items that exist only in the first set, and not in both sets.
s1.difference(s2)
# Out:
# {1, 7}

# %% [markdown]
# ## Operators with Sets

# %%
s1==s2
# Out:
# False

# %%
s1>s2
# Out:
# False

# %%
1 in s1
# Out:
# True

# %%
61 in s1
# Out:
# False

# %%
1 not in s1
# Out:
# False

# %% [markdown]
# ## Dictionaries

# %%
my_dictionary = {'key1' : 'value1','key2':'value2','key3': 'value3'}

# %%
my_dictionary['key2']
# Out:
# 'value2'

# %%
my_dictionary = {'key1' : 123456,'key2':'string','key3': '(12,33,44)'}

# %%
my_dictionary['key3']
# Out:
# '(12,33,44)'

# %%
my_dictionary = {'key1' : 123456,'key2':'string','key3': [12,33,44]}

# %%
my_dictionary['key3']
# Out:
# [12, 33, 44]

# %%
my_dictionary['key3'][1]
# Out:
# 33

# %%
my_dictionary = {'key1' : 123456,'key2':'string','key3': [12,33,44],'key4': ['item1','item2','item3']}

# %%
# The Python upper() method converts all lowercase letters in a string to uppercase and returns the modified string. 
my_dictionary['key4'][0].upper()
# Out:
# 'ITEM1'

# %%
my_dictionary['key1']
# Out:
# 123456

# %%
my_dictionary['key1'] = my_dictionary['key1'] - 123

# %%
my_dictionary['key1']
# Out:
# 123333

# %%
my_dictionary['key1'] -=123

# %%
my_dictionary['key1']
# Out:
# 123210

# %%
# empty dictionary
d={}

# %%
# creating a dictionary
d['animal'] = 'cat'

# %%
d['age'] = '3'

# %%
d['name'] = 'kitty'

# %%
d
# Out:
# {'animal': 'cat', 'age': '3', 'name': 'kitty'}

# %%
d = {'key1':{'nestkey' :{'subnestkey' : 'value'}}}

# %%
d['key1']['nestkey']['subnestkey']
# Out:
# 'value'

# %%
d = {'key1' : 2,'key2':4,'key3': 6}

# %%
# keys() method in Python Dictionary, returns a view object that displays a list of all the keys in the dictionary in order of insertion.  
d.keys()
# Out:
# dict_keys(['key1', 'key2', 'key3'])

# %%
# values() method returns a view object that displays a list of all values in a given dictionary.
d.values()
# Out:
# dict_values([2, 4, 6])

# %%
# The items() method returns a view object. The view object contains the key-value pairs of the dictionary, as tuples in a list.
d.items()
# Out:
# dict_items([('key1', 2), ('key2', 4), ('key3', 6)])

# %%
banana=[a,b,c]
for apple in banana:
  print(apple + 'na')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-b46a9925ec36> in <module>
# ----> 1 banana=[a,b,c]
#       2 for apple in banana:
#       3   print(apple + 'na')
#
# NameError: name 'a' is not defined

# %% [markdown]
# # Required Reading on Dictionaries

# %% [markdown]
# A dictionary is like a list, but more general. In a list, the index positions have to
# be integers; in a dictionary, the indices can be (almost) any type

# %% [markdown]
# You can think of a dictionary as a mapping between a set of indices (which are
# called keys) and a set of values. Each key maps to a value. The association of a
# key and a value is called a key-value pair or sometimes an ite

# %%
eng2sp = dict()
print(eng2sp)
# Out:
# {}

# %%
#The curly brackets, {}, represent an empty dictionary. To add items to the dictionary, you can use square brackets
eng2sp['one'] = 'uno'

# %%
print(eng2sp)
# Out:
# {'one': 'uno'}

# %% [markdown]
# This output format is also an input format. For example, you can create a new
# dictionary with three items. But if you print eng2sp, you might be surprised:

# %%
eng2sp = {'one': 'uno', 'two': 'dos', 'three': 'tres'}
>>> print(eng2sp)
# Out:
# {'one': 'uno', 'two': 'dos', 'three': 'tres'}

# %%
print(eng2sp['two'])
# Out:
# dos

# %%
#The len function works on dictionaries; it returns the number of key-value pairs:
len(eng2sp)
# Out:
# 3

# %% [markdown]
# The in operator works on dictionaries; it tells you whether something appears as
# a key in the dictionary (appearing as a value is not good enough)

# %%
'one' in eng2sp
# Out:
# True

# %%
'uno' in eng2sp
# Out:
# False

# %% [markdown]
# To see whether something appears as a value in a dictionary, you can use the
# method values, which returns the values as a list, and then use the in operator:

# %%
vals = list(eng2sp.values())
'uno' in vals
# Out:
# True

# %% [markdown]
# ####  Dictionary as a set of counters

# %% [markdown]
# An implementation is a way of performing a computation; some implementations
# are better than others. For example, an advantage of the dictionary implementation is that we don’t have to know ahead of time which letters appear in the string
# and we only have to make room for the letters that do appear

# %%
word = 'brontosaurus'
d = dict()
for c in word:
    if c not in d:
        d[c] = 1
    else:
            d[c] = d[c] + 1
print(d)
# Out:
# {'b': 1, 'r': 2, 'o': 2, 'n': 1, 't': 1, 's': 2, 'a': 1, 'u': 2}

# %% [markdown]
# Dictionaries have a method called get that takes a key and a default value. If the
# key appears in the dictionary, get returns the corresponding value; otherwise it
# returns the default value. For example

# %%
counts = { 'chuck' : 1 , 'annie' : 42, 'jan': 100}
print(counts.get('jan', 0))
# Out:
# 100

# %%
print(counts.get('tim', 0))
# Out:
# 0

# %% [markdown]
# We can use get to write our histogram loop more concisely. Because the get
# method automatically handles the case where a key is not in a dictionary, we can
# reduce four lines down to one and eliminate the if statement.

# %%
word = 'brontosaurus'
d = dict()
for c in word:
    d[c] = d.get(c,0) + 1
print(d)
# Out:
# {'b': 1, 'r': 2, 'o': 2, 'n': 1, 't': 1, 's': 2, 'a': 1, 'u': 2}

# %% [markdown]
# #### Looping and Dictionaries

# %%
counts = { 'chuck' : 1 , 'annie' : 42, 'jan': 100}
for key in counts:
    print(key, counts[key])
# Out:
# chuck 1
# annie 42
# jan 100

# %% [markdown]
# We can use this pattern to implement the various loop idioms that we have described earlier. For example if we wanted to find all the entries in a dictionary
# with a value above ten, we could write the following code:

# %%
counts = { 'chuck' : 1 , 'annie' : 42, 'jan': 100}
for key in counts:
    if counts[key] > 10 :
        print(key, counts[key])
# Out:
# annie 42
# jan 100

# %% [markdown]
# If you want to print the keys in alphabetical order, you first make a list of the keys
# in the dictionary using the keys method available in dictionary objects, and then
# sort that list and loop through the sorted list, looking up each key and printing
# out key-value pairs in sorted order as follows:

# %%
counts = { 'chuck' : 1 , 'annie' : 42, 'jan': 100}
lst = list(counts.keys())
print(lst)
lst.sort()
for key in lst:
    print(key, counts[key])
# Out:
# ['chuck', 'annie', 'jan']
# annie 42
# chuck 1
# jan 100
